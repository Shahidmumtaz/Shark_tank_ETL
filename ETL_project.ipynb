# %%
import pandas as pd
import numpy as np
from sqlalchemy import create_engine

# %%
load_csv = "Resources/shark_tank_companies.csv"
shark_tank_1 = pd.read_csv(load_csv)
shark_tank_1
# Out:
#     Deal                                        Description  Episode  \
# 0     No             Bluetooth device implant for your ear.        1
# 1    Yes  Retail and wholesale pie factory with two reta...        1
# 2    Yes  Ava the Elephant is a godsend for frazzled par...        1
# 3     No  Organizing, packing, and moving services deliv...        1
# 4     No  Interactive media centers for healthcare waiti...        1
# ..   ...                                                ...      ...
# 490  Yes  Zoom Interiors is a virtual service for interi...       28
# 491  Yes  Spikeball started out as a casual outdoors gam...       29
# 492  Yes  Shark Wheel is out to literally reinvent the w...       29
# 493   No  Adriana MontaNo wants to open the first Cat Ca...       29
# 494  Yes  Sway Motorsports makes a three-wheeled, all-el...       29
#
#                 Category                                      Entrepreneurs  \
# ...

# %%
# Create a filtered dataframe from specific columns
shark_tank_1_cols = ["Season", "Deal", "Category", "Valuation", "Shark1", "Shark2", "Shark3", "Shark4", "Shark5"]
shark_tank1_transformed= shark_tank_1[shark_tank_1_cols].copy()

shark_tank1_transformed
# Out:
#      Season Deal             Category  Valuation            Shark1  \
# 0         1   No            Novelties    6666667  Barbara Corcoran
# 1         1  Yes       Specialty Food    4600000  Barbara Corcoran
# 2         1  Yes  Baby and Child Care     333333  Barbara Corcoran
# 3         1   No    Consumer Services    1000000  Barbara Corcoran
# 4         1   No    Consumer Services   12000000  Barbara Corcoran
# ..      ...  ...                  ...        ...               ...
# 490       6  Yes      Online Services     500000      Lori Greiner
# 491       6  Yes       Toys and Games    5000000      Lori Greiner
# 492       6  Yes   Outdoor Recreation    2000000      Lori Greiner
# 493       6   No        Entertainment     500000      Lori Greiner
# 494       6  Yes           Automotive    3000000      Lori Greiner
#
#                Shark2           Shark3         Shark4            Shark5
# 0     Robert Herjavec    Kevin O'Leary   Daymond John  Kevin Harrington
# ...

# %%
shark_tank1_transformed = shark_tank1_transformed[shark_tank1_transformed['Deal'].notnull()]  
shark_tank1_transformed
# Out:
#      Season Deal             Category  Valuation            Shark1  \
# 0         1   No            Novelties    6666667  Barbara Corcoran
# 1         1  Yes       Specialty Food    4600000  Barbara Corcoran
# 2         1  Yes  Baby and Child Care     333333  Barbara Corcoran
# 3         1   No    Consumer Services    1000000  Barbara Corcoran
# 4         1   No    Consumer Services   12000000  Barbara Corcoran
# ..      ...  ...                  ...        ...               ...
# 490       6  Yes      Online Services     500000      Lori Greiner
# 491       6  Yes       Toys and Games    5000000      Lori Greiner
# 492       6  Yes   Outdoor Recreation    2000000      Lori Greiner
# 493       6   No        Entertainment     500000      Lori Greiner
# 494       6  Yes           Automotive    3000000      Lori Greiner
#
#                Shark2           Shark3         Shark4            Shark5
# 0     Robert Herjavec    Kevin O'Leary   Daymond John  Kevin Harrington
# ...

# %%
load_csv_file = "Resources/sharktank.csv"
shark_tank_2 = pd.read_csv(load_csv_file)
shark_tank_2
# Out:
#        Row  Season  No. in series                      Company Deal  \
# 0      NaN     NaN            NaN                          NaN  NaN
# 1      2.0     1.0            1.0             Ava the Elephant  Yes
# 2      3.0     1.0            1.0        Mr. Tod's Pie Factory  Yes
# 3      4.0     1.0            1.0                      Wispots   No
# 4      5.0     1.0            1.0  College Foxes Packing Boxes   No
# ..     ...     ...            ...                          ...  ...
# 491  492.0     6.0           28.0                 You Kick Ass  Yes
# 492  493.0     6.0           29.0                  Shark Wheel  Yes
# 493  494.0     6.0           29.0                    Gato Cafe   No
# 494  495.0     6.0           29.0             Sway Motorsports  Yes
# 495  496.0     6.0           29.0                    Spikeball  Yes
#
#                  Category Entrepreneur Gender    Amount Equity   Valuation  \
# ...

# %%
# Create a filtered dataframe from specific columns
shark_tank_2_cols = ["Season", "Deal", "Category", "Entrepreneur Gender", "Valuation", "# Sharks"]
shark_tank2_transformed= shark_tank_2[shark_tank_2_cols].copy()

shark_tank2_transformed
# Out:
#      Season Deal              Category Entrepreneur Gender   Valuation  \
# 0       NaN  NaN                   NaN                 NaN         NaN
# 1       1.0  Yes            Healthcare              Female     $90,909
# 2       1.0  Yes     Food and Beverage                Male    $920,000
# 3       1.0   No     Business Services                Male         NaN
# 4       1.0   No      Lifestyle / Home                Male         NaN
# ..      ...  ...                   ...                 ...         ...
# 491     6.0  Yes  Children / Education              Female  $1,000,000
# 492     6.0  Yes      Fitness / Sports                Male  $3,000,000
# 493     6.0   No     Uncertain / Other              Female         NaN
# 494     6.0  Yes       Green/CleanTech                Male  $1,500,000
# 495     6.0  Yes      Fitness / Sports                Male  $2,500,000
#
#      # Sharks
# 0         NaN
# 1         1.0
# 2         2.0
# 3         0.0
# 4         0.0
# ..        ...
# ...

# %%
shark_tank2_transformed.count()
# Out:
# Season                 495
# Deal                   495
# Category               495
# Entrepreneur Gender    495
# Valuation              244
# # Sharks               495
# dtype: int64

# %%
shark_tank2_transformed = shark_tank2_transformed[shark_tank2_transformed['Deal'].notnull()]  
shark_tank2_transformed
# Out:
#      Season Deal              Category Entrepreneur Gender   Valuation  \
# 1       1.0  Yes            Healthcare              Female     $90,909
# 2       1.0  Yes     Food and Beverage                Male    $920,000
# 3       1.0   No     Business Services                Male         NaN
# 4       1.0   No      Lifestyle / Home                Male         NaN
# 5       1.0   No     Uncertain / Other                Male         NaN
# ..      ...  ...                   ...                 ...         ...
# 491     6.0  Yes  Children / Education              Female  $1,000,000
# 492     6.0  Yes      Fitness / Sports                Male  $3,000,000
# 493     6.0   No     Uncertain / Other              Female         NaN
# 494     6.0  Yes       Green/CleanTech                Male  $1,500,000
# 495     6.0  Yes      Fitness / Sports                Male  $2,500,000
#
#      # Sharks
# 1         1.0
# 2         2.0
# 3         0.0
# 4         0.0
# 5         0.0
# ..        ...
# ...

# %%
merged_shark_tank = pd.merge(shark_tank1_transformed, shark_tank2_transformed, on=["Season", "Deal", "Category"], how="outer")
merged_shark_tank
# Out:
#      Season Deal           Category  Valuation_x            Shark1  \
# 0         1   No          Novelties    6666667.0  Barbara Corcoran
# 1         1   No          Novelties     750000.0  Barbara Corcoran
# 2         1   No          Novelties     166667.0  Barbara Corcoran
# 3         1   No          Novelties     757576.0  Barbara Corcoran
# 4         1   No          Novelties     430000.0  Barbara Corcoran
# ..      ...  ...                ...          ...               ...
# 983       6  Yes  Uncertain / Other          NaN               NaN
# 984       6  Yes    Green/CleanTech          NaN               NaN
# 985       6  Yes    Green/CleanTech          NaN               NaN
# 986       6  Yes    Green/CleanTech          NaN               NaN
# 987       6   No  Uncertain / Other          NaN               NaN
#
#               Shark2         Shark3        Shark4            Shark5  \
# 0    Robert Herjavec  Kevin O'Leary  Daymond John  Kevin Harrington
# ...

# %%
shark_tank_df.describe()
# Out:
#            askedFor  exchangeForStake     valuation
# count  4.230000e+02        423.000000  4.230000e+02
# mean   2.642080e+05         17.728132  2.181086e+06
# std    4.880481e+05         10.400252  3.864441e+06
# min    1.000000e+04          3.000000  4.000000e+04
# 25%    7.500000e+04         10.000000  4.000000e+05
# 50%    1.500000e+05         15.000000  9.000000e+05
# 75%    2.500000e+05         20.000000  2.000000e+06
# max    5.000000e+06        100.000000  3.000000e+07

# %%
shark_tank_category = merged_shark_tank.groupby("Category")
shark_tank_category

# %%
shark_tank_cleaned1 = merged_shark_tank.drop_duplicates("Category")
shark_tank_cleaned1
# Out:
#      Season Deal                 Category  Valuation_x            Shark1  \
# 0         1   No                Novelties    6666667.0  Barbara Corcoran
# 5         1  Yes           Specialty Food    4600000.0  Barbara Corcoran
# 10        1  Yes      Baby and Child Care     333333.0  Barbara Corcoran
# 13        1   No        Consumer Services    1000000.0  Barbara Corcoran
# 16        1   No  Men and Women's Apparel    1000000.0  Barbara Corcoran
# ..      ...  ...                      ...          ...               ...
# 533       1   No         Fashion / Beauty          NaN               NaN
# 548       1   No    Media / Entertainment          NaN               NaN
# 550       1  Yes          Software / Tech          NaN               NaN
# 556       1  Yes         Fitness / Sports          NaN               NaN
# 571       1   No          Green/CleanTech          NaN               NaN
#
#               Shark2         Shark3        Shark4            Shark5  \
# ...
